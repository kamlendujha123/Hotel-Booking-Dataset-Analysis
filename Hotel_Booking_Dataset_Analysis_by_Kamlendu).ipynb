# %% [markdown]
# <a href="https://colab.research.google.com/github/kamlendujha123/Hotel-Booking-Dataset-Analysis/blob/main/Hotel_Booking_Dataset_Analysis_by_Kamlendu).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Dataset Analysis

# %% [markdown]
# ##### **Project Type**    - EDA (Exploratory Data Analysis)
# ##### **Project Name**    - Hotel Booking Dataset Analysis
# ##### **Contribution**    - Individual
# ##### **Auther** - Kamlendu Kumar Jha

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# # The Hotel Booking Analysis EDA project is my an individual initiative.
# This project aims to analyze the Hotel Booking Dataset, which includes two types of data (City Hotels, Resort Hotels). Our primary goal is to focus on understanding key factors influencing bookings, identifying patterns of cancellation behavior, and determining the impact of various features on customer experiences and satisfaction.
#
# The dataset provides detailed information related to lead time, type of meal, customer type, and many more. Our analysis aims to uncover insights that can guide the formulation of strong strategies and decision-making for hotel management.
#
# **Work Flow :**
# The hotel booking dataset contained 119,390 rows and 32 columns. Within this dataset, a total of 31,994 duplicate values were identified, and missing values were present in a few columns. The initial step involved analyzing the dataset, followed by the removal of duplicate values and the replacement or removal of missing/null values.
#
# After these data cleaning steps, two additional columns were created to enhance the understanding and meaning analysis of the dataset. Furthermore, some columns exhibited incorrect data types, prompting the correction of these columns by adjusting them to the appropriate data types.
#
# To facilitate a more comprehensive analysis, visualizations were generated for multiple columns with significant relevance in the dataset.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/kamlendujha123/Hotel-Booking-Dataset-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# - The provided dataset contains Hotel Booking Information for both City and Resort types of hotels. Our goal is to analyze all the data within the dataset and explore the patterns, trends, and relationships in hotel bookings. We will conduct exploratory data analysis on this dataset, which comprises 119,390 rows and various attributes related to hotel bookings.
#
# - What are the primary factors contributing to hotel booking cancellations, and how can these be minimized to enhance hotel revenue and occupancy rates?
#
# - How does lead time (the time between booking and arrival) impact booking behavior, and what strategies can be employed to optimize room availability and pricing?
#
# - What are the most popular room types, meal preferences, and special requests made by guests, and how can we provide the best quality of services and attractive offers to customers and guests?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Increase hotel profitability and enhance guest experience by leveraging data insights to optimize booking strategies, minimize cancellations, and increse the total revenue for both City and Resort Hotels.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data_path='/content/drive/My Drive/Datasets/Hotel Bookings.csv'
df=pd.read_csv(data_path,encoding='ISO-8859-1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows,columns=df.shape
print(f'There are total {rows} rows and {columns} columns in this dataset ')
# Out:
# There are total 119390 rows and 32 columns in this dataset

# %%
# Total number of values in Dataset
df.size
# Out:
# 3820480

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dup=df.duplicated().sum()
print(f" In the hotel_booking dataset there are Total : {dup} duplicate values present")
# Out:
#  In the hotel_booking dataset there are Total : 31994 duplicate values present

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
# as we can see there are missing values in four columns of the dataset so will visualize those columns
missing_column=['country','agent','company','children']
colors=['red','blue','pink','green']
missing_column_percent=(df[missing_column].isnull().mean())*100
plt.bar(missing_column,missing_column_percent,color=colors)
plt.title('Visualization of null values in dataset')
plt.xlabel('missing_column')
plt.ylabel('missing_column_percent')
plt.show()
# Here i have shown the average missing values in those three columns which contain missing values

# %% [markdown]
# Here i have a plotted a pie chart of missing values in those columns which contains null values.

# %%
missing_columns=['country','agent','company']
val1=df['country'].isnull().sum()
val2=df['agent'].isnull().sum()
val3=df['company'].isnull().sum()
vals=[val1,val2,val3]
ex=[0.0,0.0,0.1]
plt.pie(x=vals,labels=missing_columns,colors=['red','Blue','green'],autopct='%.2f%%',explode=ex)
plt.title('pie plot proportion of missing columns')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In the hotel booking analysis Dataset contains Total 119390 rows and 32 columns which makes 3820480 data..but it contains 31994 duplicate rows in the Dataset so i removed those rows from the dataset to make visualization better after removing duplicate values data became(rows=87396,columns=32,total_data=2796672)...but in the Dataset there's missing or null values too and all missing values were present in basically three columns (country=452, agent=12193,  company=82137).
# Now with this Dataset we can perform exploratory Data analysis (EDA) to know the valueble insights of hotel booking pattern and trends and also the relation how customers do booking.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# -  Hotel- This column represents the type of hotel.
# -  is_canceled - This column basically represents that weather the booking cancelled or not.
# -  lead_time - This column represents the difference of days between finding booked date and entering hotel room.
# -  arrival_date_year - This column represents the year of arrival date.
# -  arrival_date_month - This column represents the month of arrival date.
# -  arrival_date_week_number - This column represents the day of week number of arrival date.
# -  arrival_date_day_of_month - This column represents the day of month of arrival date.
# -  stays_in_weekend_nights - This column represents that how many nights stayed in weekend.
# -  stays_in_week_nights - This column represents that how many nights stayed in week days.
# -  adults - This column represents that how many adults will come to stays for each booking.
# -  children - This column represents that how many children will come to stays for each booking.
# -  babies - This column represents that how many babies will come to stays for each booking.
# -  meal - what kind of meal that opted while stays.
# -  country - This column represents Country code of customer who booked
# -  market_segment - This column represents from which market the customer belongs.
# -  distribution_channel - How The customer Accessed the stayed corporate booking direct/TA.TO
# -  is_repeated_guest - This column represents that is this guest visited in past or not.
# -  previous_cancellations - This column reresents that is this guest cancelled booking of rooms in past ever.
# -  previous_bookings_not_canceled - This column represents that this guest not cancelled booking of rooms in past ever.
# -  reserved_room_type - This column represents what type of room reserved.
# -  assigned_room_type - This column represents what types of room was assigned.
# -  booking_changes - This column represents that does any changes happend after booking.
# -  deposit_type - This column represents Type of deposit.
# -  Agent- This column represents the agent number.
# -  company - This column represents company code customer.
# -  days_in_waiting_list - This column represents Days of waiting list to get booking
# -  customer_type - This column represents Type of Customer.
# -  adr - This column represents the average daily rates of booking.
# -  required_car_parking_spaces - This column represents how much space was taken for car parking.
# -  total_of_special_requests- This column represents that number of special guest or vip customer.
# -  reservation_status- This column represents status of reservation.
# -  reservation_status_date- This column represents Date of specific status.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
  print(f" There  are Total {df[column].nunique()} values in the {column}. ")
# Out:
#  There  are Total 2 values in the hotel.
#  There  are Total 2 values in the is_canceled.
#  There  are Total 479 values in the lead_time.
#  There  are Total 3 values in the arrival_date_year.
#  There  are Total 12 values in the arrival_date_month.
#  There  are Total 53 values in the arrival_date_week_number.
#  There  are Total 31 values in the arrival_date_day_of_month.
#  There  are Total 17 values in the stays_in_weekend_nights.
#  There  are Total 35 values in the stays_in_week_nights.
#  There  are Total 14 values in the adults.
#  There  are Total 5 values in the children.
#  There  are Total 5 values in the babies.
#  There  are Total 5 values in the meal.
#  There  are Total 177 values in the country.
#  There  are Total 8 values in the market_segment.
#  There  are Total 5 values in the distribution_channel.
#  There  are Total 2 values in the is_repeated_guest.
#  There  are Total 15 values in the previous_cancellations.
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code
#
# ##The Hotel booking analysis Dataset contains Total 119390 rows and 32 columns which makes Total 3820480 data but in this Dataset there are some Duplicate values are there.Duplicate rows - 31994 and also missing/Null values present . so we will first remove the duplicate values from the Dataset by using drop_duplicates() method.
#
# ## so here are some important Steps to do in the Dataset for better analysis.
# ###1. Remove duplicate rows
# ###2. Handling Missing values
# ###3. Convert columns to appropriate datatypes
# ###4. Adding some new columns - total guests and total nights stayed

# %% [markdown]
# ### step 1- Removing Duplicate value from Dataset

# %%
# Dataset Duplicate Value Count
dup=df.duplicated().sum()
print(f" In the hotel_booking dataset there are Total : {dup} duplicate values present")
# Out:
#  In the hotel_booking dataset there are Total : 31994 duplicate values present

# %%
# Removing Duplicate value from Dataset
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Step 2 - Handling missing values and Null Values.

# %%
df.shape
# Out:
# (87396, 32)

# %%
# handling missing and null values
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %% [markdown]
# In our hotel booking dataset the company, agent,country,chirldren column contains null values. Now lets understand why well agent column represents agent number so definitely there will be some customer who booked the hotel rooms directly that's why that rows contain Null values.similarly in company column There are some customer who doesn’t like tell country code that’s why it contains null values.And same for Company column
#  so for better understanding we will replace the null values to 0.

# %%
# Here we will not use this (df.replace(np.NaN,0,inplace=True)) method because it will replace all with Zwro but in dataset different column has different reason for null values so will use fillna() function
# now replacing missing value to 0 .
df['agent'].fillna(0,inplace=True)
df['company'].fillna(0,inplace=True)
df['children'].fillna(0,inplace=True)

# %% [markdown]
# - now removing the country column's missing value because there's no sense for putting unknown or anthing as i saw there are total 452 rows only and our dataset still contains 87396 rows.

# %%
df.dropna(subset=['country'],inplace=True)

# %%
# checking again is null values removed or not.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86944 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86944 non-null  object
#  1   is_canceled                     86944 non-null  int64
#  2   lead_time                       86944 non-null  int64
#  3   arrival_date_year               86944 non-null  int64
#  4   arrival_date_month              86944 non-null  object
#  5   arrival_date_week_number        86944 non-null  int64
#  6   arrival_date_day_of_month       86944 non-null  int64
#  7   stays_in_weekend_nights         86944 non-null  int64
#  8   stays_in_week_nights            86944 non-null  int64
#  9   adults                          86944 non-null  int64
#  10  children                        86944 non-null  float64
#  11  babies                          86944 non-null  int64
# ...

# %%
# Here df is my DataFrame which containing the hotel booking data
print(f" The length of our Dataset Before Removing : {len(df)}")

# i've to filter rows where the sum of adults, children, and babies is zero because atleast any one of then should come then booking possibe
mask = df[df['adults'] + df['children'] + df['babies'] == 0]
# now i stored value into a appropriate variable.
rows_with_zero_count = mask
# Display the length of rows who's is equal to Zero.
print(f" There are total {len(rows_with_zero_count)}")
# Out:
#  The length of our Dataset Before Removing : 86944
#  There are total 161

# %%
# Now Removed those rows from dataset which is sum of children,adult,babies are zero
df.drop(rows_with_zero_count.index,inplace=True)
print(f" After Removing those rows the length of Dataset :{len(df)}")
# Out:
#  After Removing those rows the length of Dataset :86783

# %% [markdown]
# ### Step (3) Now converting The tyoe of Data of Those column data type which is incorrect for our analysis so i found three columns children,agent,company.

# %%
# converting the columns data type into float to integer
df[['children','agent','company']]=df[['children','agent','company']].astype(int)

# %%
# Now checking Data Type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86783 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86783 non-null  object
#  1   is_canceled                     86783 non-null  int64
#  2   lead_time                       86783 non-null  int64
#  3   arrival_date_year               86783 non-null  int64
#  4   arrival_date_month              86783 non-null  object
#  5   arrival_date_week_number        86783 non-null  int64
#  6   arrival_date_day_of_month       86783 non-null  int64
#  7   stays_in_weekend_nights         86783 non-null  int64
#  8   stays_in_week_nights            86783 non-null  int64
#  9   adults                          86783 non-null  int64
#  10  children                        86783 non-null  int64
#  11  babies                          86783 non-null  int64
# ...

# %% [markdown]
# ### Step(4) now we will add two more columns because it will make the dataset more meaningful let's see

# %%
# Now creating new two columns in our dataset for better analysis.
df['total_guests']=df['children']+df['adults']+df['babies']
df['total_nights_stayed']=df['stays_in_week_nights']+df['stays_in_weekend_nights']

# %%
# now checking the number of columns and whatever columns i added that's added or not.
len(df.columns)
# Out:
# 34

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I have completed four steps of manipulation in the dataset:
#
# - Step (1) : Removing Duplicate Values: In the dataset, various duplicate values were present. I removed those duplicate values using the drop_duplicates() function, resulting in a duplicate-free dataset.
#
# - Step (2) : Replacing Null Values: The second step involved replacing null values or missing values with appropriate values to make the dataset null-values-free and more readable. Specifically, only four columns—'agent,' 'country,' 'company,' and 'children'—contained missing values. I replaced the null values in the 'agent,' 'company,' and 'children' columns with 0. For the 'country' column, I replaced null/missing values with 'unknown.'
#
# - Step (3) : Changing Data Types: The third step focused on changing the data type of a few columns because they were in the incorrect data type. I converted the data type of the 'children,' 'agent,' and 'company' columns from float to integer.
#
# - Step (4) : Adding Two New Columns: In the fourth step, I added two new columns to the dataset for better analysis. The first column, 'total_nights_stayed,' represents the sum of 'stays_in_week_nights' and 'stays_in_weekend_nights.' The second column, 'total_guests,' is the sum of 'children,' 'adults,' and 'babies.'
#
# - Insights from the Dataset:
#     - There is a 'hotel' column that distinguishes between city hotels and resorts.
#     - The 'country' column provides a country code, allowing analysis of the country from which the most guests originated.
#     - The 'arrival_date_month' column offers insights into the preferred months for holiday visits.
#     - Columns like 'children,' 'adults,' and 'babies' help analyze the age preferences of guests.
#     - The 'meal' column indicates the guests' preferred type of food.
#     - The 'reserved_room_type' column assists in analyzing the most requested room types by guests.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
#
# which type of hotel is most preferable by the customers?

# %%
# Chart - 1 visualization code
hotel_type=df['hotel'].value_counts().index
val=df['hotel'].value_counts()
plt.pie(x=val,labels=hotel_type,autopct='%.2f%%',colors=['Green','Red'])
plt.title('pie chart of hotel-type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected this chart to illustrate the most preferred types of hotels by customers and the proportion differences between them. Since the column under consideration has a relatively low number of unique values, and the analysis requires a univariate chart, a pie chart is well-suited for this purpose. From the chart, it is evident that customers mostly prefer city hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here i found That City-hotels are more preferable by the customer to stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This chart holds significance for the business because it allows easy analysis, revealing that city hotels receive nearly twice as many bookings as resort hotels. Investors may consider directing their funds towards city hotels rather than resort hotels. By initially investing in city hotels, the capital can be utilized to improve the quality of products, food, and services. As we start providing more facilities, the demand is likely to increase, resulting in higher revenue and profits. Concerning negative impacts, I don't foresee any. However, consideration should also be given to market strategies and better offers to further optimize outcomes.

# %% [markdown]
# #### Chart - 2
#
# Now we'll analyse in which month customer do booking mostly?

# %%
# Chart - 2 visualization code
# Here we will make a column Chart for representing the month and booking in each month.
booking=df['arrival_date_month'].value_counts()
months=df['arrival_date_month'].value_counts().index
ax=sns.barplot(x=booking,y=months,hue=months)
for i,v in enumerate(booking):
  ax.text(v+3,i,str(v))
plt.title("Month-wise booking")
plt.xlabel('Month-bookings count')
plt.ylabel('Month name')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here We have picked the column chart because first of all it's a bivariate chart.which is needed here for representing the month wise booking. and our variables were month name and month total booking but why column instead of bar chart because it makes more readable for representing these column length of value-name was long so that's the reason for it.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight of this chart is that from the starting  of march till end of august there are huge number of  customer do bookings for their holidays plan or exploring things.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yeah, as observed in the column chart, from March to August, most people make bookings for their holidays or leaves. So, the hotel and resort management team needs to strategize for these months. They should put in efforts to enhance facilities, ensure available rooms, improve service quality, offer attractive deals, and select well-behaved staff with good communication skills, along with maintaining the quality of food.
#
# All these aspects should be addressed. By implementing these measures, the demand for hotels and room bookings will certainly increase, leading to more revenue and profits.
#
# Regarding negative growth, from September to February, when there is a lower number of bookings and customers may not consider trips and holidays, it is a golden time to strategize for providing the best quality stays and great experiences. This period does not significantly impact our management. However, if these measures are not executed in an organized and well-mannered way, it could result in negative growth.

# %% [markdown]
# #### Chart - 3
#
#   Total Number of bookings based on different different market segments.

# %%
# Chart - 3 visualization code of overall market segment

market_segments=df['market_segment'].value_counts().index
bookings=df['market_segment'].value_counts()

col=['red','blue','green','pink','yellow','black','orange','magenta']
plt.subplot(2,1,1)
sns.barplot(x=bookings,y=market_segments,palette=col)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(x='market_segment',data=df[df['hotel']=='City Hotel'],palette='pastel')
plt.xlabel('bookings')
plt.ylabel('market segment for city hotels')
plt.xticks(rotation=45,ha='right')
plt.subplot(1,2,2)
sns.countplot(x='market_segment',data=df[df['hotel']=='Resort Hotel'],palette='pastel')
plt.xlabel('bookings')
plt.ylabel('market segment for Resort hotels')
plt.xticks(rotation=45,ha='right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here first i plotted a column bar chart to show overall bookings on the basis of market segments then  i'll pick two count chart for analysing the booking distribution on the basis of market segments with different different types of hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the first chart which is column bar chart i plotted Because in that i have to show that bboking details according to the defferent-different booking segments. In which i found that Online TA segment has the most bookings .but i realised that it would be great if i plot two different- different plot in which one for city hotels and one for resort hotels so it will easy to analyse that for which type of hotels have most bookings based on segments.
#   - Now let's come to the point that what i found from the these charts so firstly i can say that from first chart i found the Online TA - segments has the most  number of bookings and at second number it's Offline TA/TO in tjis list..
#   - I tried to visualise that for city hotels which segmet has most bookings so i found that at first  Online TA and at second offline TA/TO similarly for Resort hotels Online TA has the most number of bookings..
#   - In both the hotels i see that Direct booking market sements is very less .
#   - And Complementry booking is also very less in both types of hotels .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yaah definitely the plot will help .now let's understand the logic here how to increase the booking understanding by this plots and charts.
#   #(1) in the first plot which is based on Market segments and number of bookings i found that the online TA has huge or most number of bookings it means Those customer who search or book rooms they are mostly by online Travel agencies it means at online travel agencies our review is great that's why they prefere our hotels first so we can provide them more avaliable rooms as much possible so we will get more bookings.
#   #(2) In the the first plot i found that complementry market segments booking is very less it means those customers who wants discount and offers they don't prefere out rooms so it may be the reason tha our offers are not effective so we need to look inro this and we need to provide them some special offers and good discouts that they will book our rooms.
#   #(3) Now in the second plot which is subplot here i ploted two plots first one for city hotels where i saw that in the Online TA has most number of bookings but corporate segments booking is low it means those customore who's are regular for any hotels they don't prefere our hotel rooms so there are two main reasons can cause here first- they don't like our rooms or quality of rooms and second - Price of rooms so we need to work on these things . if our room price is high then we will give discount to the corporate segments customer or if the quality is the reason then we will impove the quality of rooms .once they will like our rooms then automatically our adr (average daily revenue) will be increase of hotels.
#   #(4) I also saw that the complementary segments booking is very less in both (Resort and city hotels ).it means that those customers who wants complementary for rooms bookings they don't prefere so for them we can start providing the attractive offers and discounts for out room bookings.

# %% [markdown]
# #### Chart - 4
#
#   Types of meals prefered by customer/guest.

# %%
# Chart - 4 visualization code
meal_type=df['meal'].value_counts().index
meals=df['meal'].value_counts()
plt.pie(meals,labels=meal_type,autopct='%.1f%%',colors=['lightgreen','blue','green','pink','orange'])
plt.xlabel('Meal type')
plt.ylabel('Meals prefered asked ')
plt.title('Bar plot of meal type vs meal booking value')
plt.show()

# %%
# Chart - 4 visualization code
meal_type=df['meal'].value_counts().index
meals=df['meal'].value_counts()
plt.bar(meal_type,meals,color=['red','blue','green','pink','orange'])
plt.xlabel('meal type')
plt.ylabel('meals prefered asked ')
plt.title('Bar plot of meal type vs meal booking value')
plt.show()
meals
# Out:
# BB           67495
# SC            9389
# HB            9051
# Undefined      488
# FB             360
# Name: meal, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here i am plotting Bar plot to visualise that which kind of meals customers or guests prefere while booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#   #(1)In this bar chart i represented the types of meals on x-axis and how many times customer prefered that meal ordered on y-axis.
#   #(2) In this bar chart i analysed that the BB( Bed and Breakfast ) has liked most by the customer.
#   #(3)on the second number it's SC (Self-catering) is also picked by the customer in which customer or guest are responsible by itself for their meals.
#   #(4) in the chart i saw very less time the FB(Full board- in which breakfast ,lunch,snacks,dinner comes with) meals was ordered while booking. similarly HB(Half board- breakfast,lunch comes with) was asked while booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In this graph or chart, we observe that most people are choosing the BB (Bed and Breakfast) plans for their meals, and the second preference is SC (Self-Catering). There are reasons for this trend:
#
# -  Online Travel Agencies (OTAs): Many customers who visit hotels or resorts do so through Online Travel Agencies. These travelers often spend the entire day exploring and may not find time for lunch or dinner during their stay.
#
# -  Price Factor: Hotel food tends to be more expensive than options available outside. Customers may choose to dine at restaurants or other eateries to save on costs. Therefore, it's crucial to assess the cost and margin of the meals. If the margin appears high, adjustments should be made to decrease meal prices.
#
# -  Low Preference for FB (Full Board) and HB (Half Board): The chart indicates that a small percentage of customers opt for Full Board or Half Board when booking. Strategies should be devised to increase the inclusion of meals in bookings. Offering complimentary items or services can be a compelling incentive to attract guests to choose meal plans during booking.
#
# -  Profit Margin and Quality: By implementing a lower profit margin on meals and ensuring high-quality food, hotels can encourage customers to include meal plans with their room bookings. Providing additional perks without extra charges can also enhance the overall value proposition for guests.
#
# -  Addressing these factors will likely result in increased meal plan bookings, making it essential to strike a balance between pricing, quality, and added value to meet customer preferences.

# %% [markdown]
# #### Chart - 5
#
# Top 10 Agents who does Most number of bookings.

# %%
# Chart - 5 visualization code
val=df['agent'].value_counts().head(10)
print(val)
agents_id=df['agent'].value_counts().head(10).index
print(agents_id)
# Out:
# 9      28720
# 240    12977
# 0      11821
# 14      3341
# 7       3294
# 250     2764
# 241     1641
# 28      1493
# 8       1383
# 1       1228
# Name: agent, dtype: int64
# Int64Index([9, 240, 0, 14, 7, 250, 241, 28, 8, 1], dtype='int64')

# %%
data={'agent_id':agents_id,'bookings_count':val}
my_df=pd.DataFrame(data)
print(my_df)
# Out:
#      agent_id  bookings_count
# 9           9           28720
# 240       240           12977
# 0           0           11821
# 14         14            3341
# 7           7            3294
# 250       250            2764
# 241       241            1641
# 28         28            1493
# 8           8            1383
# 1           1            1228

# %%
sns.barplot(x='agent_id',y='bookings_count',palette='pastel',hue='agent_id',data=my_df)
plt.title('visualization Total booking through top 10 agents' )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here i picked this chart because i want to visualise the top 10 agents id who does booking and their performance .so i used a Bar chart in which i can easily presents that theie total number of booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#   These are the following insights that i found from the chart.
# - In this Bar plot i shown the top 10 Agent's performance in booking number so i saw that agent_id=9 has most number of bookings-28721.
# - agent_id=240 has second most number of bookings-13028.
# - agent_id-0 and agent_id-240,and agent_id-9 only these threes has above than 10000 bookings and rest of booking id has less than 10000 bookings.
# - Agents with IDs 1, 7, 8, 14, 28, 241, and 250 have bookings ranging below 5,000. These agents are performing well but have relatively lower booking counts compared to the top agents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this plot will definitely have a positive impact on the business. As we observed, agent_id-9 and agent_id-240 have made more than 10,000 bookings. Therefore, we can collaborate or form partnerships with them. It is advisable to provide them with additional incentives to strengthen the partnership, motivating them to generate more bookings.
#
# For those agents with fewer bookings, it is essential to communicate with them and understand the reasons behind the lower numbers. Taking necessary steps based on this information will be crucial.

# %% [markdown]
# #### Chart - 6
#
# Types of customer and which types of customer does most number of bookings.

# %%
# Chart - 6 visualization code
city_data=df[df['hotel']=='City Hotel']
booking1=city_data['customer_type'].value_counts()
city_customer_type=city_data['customer_type'].value_counts().index
resort_data=df[df['hotel']=='Resort Hotel']
booking2=resort_data['customer_type'].value_counts()
resort_customer_type=resort_data['customer_type'].value_counts().index

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(x=city_customer_type,y=booking1,palette='pastel',legend=False,hue=city_customer_type)
plt.title('City hotels booking based on customer type')
plt.xticks(rotation=45,ha='right')
plt.subplot(1,2,2)
sns.barplot(x=resort_customer_type,y=booking2,palette='pastel',legend=False,hue=resort_customer_type)
plt.title('resort hotel booking based on customer type')
plt.xticks(rotation=45,ha='right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I created two bar plots. The first one illustrates bookings at a city hotel based on customer type, while the second one depicts bookings at a resort hotel based on customer type. The intention is to highlight which customer types make the most bookings and which ones make fewer bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights derived from this chart require an understanding of the various types of customers. These include:
#
# - Transient: Individual guests or small groups booking rooms for short durations. Transient guests often include tourists, business travelers, or those with short-term accommodation needs, not bound by long-term contracts or group bookings.
#
# - Contract: Guests with long-term agreements or contracts with the hotel. This category may encompass corporate clients or individuals with negotiated deals for extended stays.
#
# - Transient-Party: A combination of transient guests who are part of a group, which could include families or friends traveling together. However, the booking is still considered transient rather than a long-term contract.
#
# - Group: Represents bookings for large groups, such as tour groups or conference attendees. Group bookings often entail special arrangements or discounts.
#
# - For city hotels:
#
# Transient customers make the most bookings - 44,522.
# Transient-Party is the second-highest with 7,016 bookings.
# For resort hotels:
#
# Transient customers again lead with 27,340 bookings.
# Transient-Party follows with the second-highest bookings at 4,676.
# Group bookings have a significantly lower number at 272.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As demonstrated in the bar plots, it is evident that the Transient type of customer has the highest number of bookings in both city and resort hotels, which is a positive aspect of our management. However, concerning the Group and Contract types of customers, there are notably fewer bookings. This suggests that groups of people may not prefer to stay in our hotels. To address this situation, we need to attract Group customers, and to do so, we can offer:
#
# - For the booking of 3 rooms, 1 extra room is completely free.
# - For a minimum five-day booking, provide 2 days as complimentary.
# - Introduce additional discounts.
# Implementing these incentives will likely attract more Group customers, contributing to an increase in the Average Daily Revenue (ADR). Similar strategies can be applied to attract Contract customers.

# %% [markdown]
# #### Chart - 7
#
# Most Demandable rooms by customer and assigned rroms by hotels managements.

# %%
# Chart - 7 visualization code

room_type=df['reserved_room_type'].value_counts().index
number_of_rooms=df['reserved_room_type'].value_counts()
assigned_rooms_type=df['assigned_room_type'].value_counts().index
assigned_rooms_count=df['assigned_room_type'].value_counts()
# chart of reserved rooms by customer
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
col=['blue','red','green','pink','green','magenta','black','yellow','grey']
sns.barplot(x=room_type,y=number_of_rooms,palette=col,hue=room_type)
plt.xlabel('type of rooms')
plt.ylabel('Reserved rooms for each type')
plt.title('reserved rooms by customer in percent value')
# chart of assigned rooms by hotels management
plt.subplot(1,2,2)

col1=['blue','red','green','pink','green','magenta','black','yellow','grey','silver','gold']
sns.barplot(x=assigned_rooms_type,y=assigned_rooms_count,palette=col1,hue=assigned_rooms_type,legend=False)
plt.xlabel('type of rooms')
plt.ylabel('Reserved rooms for each type')
plt.title('assigned rooms by hotel management ')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the Two many Bar-Plots here to show what kind of rooms demanded by customer and what kind of rooms the hotel management team assign them.and visualise the Data to understand the pattern.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this chart i found variois kind of insights ..i plotted here two plots first for reserverd room type and second for assigned room types.
#
# For Reserved room types-**
#   - In this chart i found  mostly customers want (A) type of rooms and Total count of room type A is 56436 .
#   - In this list at the second number (D) type of rooms is most demandable and the count of room type (D) is 17376.
#   - But as i can see rest type of rooms has very less number of bookings by customer.less than 7000.
#
# For Assigned room types-**
#
#   - In the list of assigning rooms as customer asked for booking for (A) type of room mostly so hotel management has also provide them (A) type of rooms and if we talk about the number then he has total 46283 times they provided (A) rooms so it's impressive.
#   - Now According to the demand of room type (B) by the customer it was 17376 and they provided more than demand of count 22419..so it's very well management i can say by the hotel management.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yaah As i plotted Two Bar-Plots here in which we can easily see what are the most demandable rooms for the customer and they want to stay and what are the rooms which are assigned to customer by hotel management.
# - So the point is that how my gained insights will the business for positive impact so by visualising these plots and make the stratigies like they can incease the price of most preferable rooms for making more revenue .
# - Now those rooms which has less number of bookings we can do few more things to attract customer for more bookings like- wise decrease the pricing and give better hopitality and servics in those rooms .after these steps it's possible to get more bookings in those rooms also.
# - Now from hotel management point of view i wiil recomanded that those rooms which customer does not prefere mostly. so we can convert these rooms into those types of rooms which are most preferable by customer by doing needful changes .
# - As for negative growth, one potential concern could be the underutilization of less popular room types. If certain room types consistently receive very few bookings, it may lead to revenue loss and inefficiency in resource allocation. However, by offering targeted promotions and packages for these room types, hotels can try to improve their utilization and mitigate any negative impact.

# %% [markdown]
# #### Chart - 8
#
# Total revenue for City and Resort hotels.

# %%
# Chart - 8 visualization code
# filtering data on hotel types.
city_df=df[df['hotel']=='City Hotel'].copy()
resort_df=df[df['hotel']=='Resort Hotel'].copy()
# calculating revenue for hotel seperately
city_df['city_revenue']=city_df['adr']*city_df['total_nights_stayed']
resort_df['resort_revenue']=resort_df['adr']*resort_df['total_nights_stayed']

# %%
# printing revenue columns
total_city_revenue=city_df['city_revenue'].sum()
total_resort_revenue=resort_df['resort_revenue'].sum()
# now plotting the column in barplot
sns.barplot(x=['city hotel','resort hotel'],y=[total_city_revenue,total_resort_revenue],palette=['Blue','yellow'],hue=['city hotel','resort hotel'])
plt.ylabel('total Revenue')
plt.title('Total Revenue of Both types of hotels ')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have picked here a Bar plot to visualise the total revenue of each hotel types..
# Here it can effectively compare the revenue generated by each typpe of hotel in a clear and stright forward manner.
# The Bar chart allows us for easy comparision between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this Bar chart i found that There is huge gap in between city hotels and resort hotels.where as city hotel Revenue is more than 1.75 million and the resort type hotel has almost 1.58 million revenue.and as i believe it's far well.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The bar plot I created will undoubtedly aid the management in analyzing the total revenue of both types of hotels (Resort hotels and City hotels).
#
# Positive impacts include:
#
# - Strong Demand: Both hotel types show a robust demand for room bookings and accommodation in city and resort locations. This continuous demand serves as a foundation for ongoing revenue generation.
#
# - Revenue Milestone: It's noteworthy that both types of hotels have surpassed 1.5 million in revenue. This achievement is promising, and with a strong mindset and effective strategies, there is potential to further increase total revenue in both hotel types. To achieve this, a thorough understanding of market needs and well-executed marketing plans are essential.
#
# - As for negative growth, there doesn't seem to be any evident in the provided dataset. Both hotels are generating substantial revenue. The key focus should be on maintaining consistent service delivery to sustain this positive trend.

# %% [markdown]
# #### Chart - 9
#
# plot for top 10 countries booking in our hotels

# %%
top_country=df['country'].value_counts().head(10)
country_name=df['country'].value_counts().head(10).index
print(top_country)
print(country_name)
# Out:
# PRT    27355
# GBR    10424
# FRA     8823
# ESP     7244
# DEU     5385
# ITA     3061
# IRL     3015
# BEL     2081
# BRA     1993
# NLD     1910
# Name: country, dtype: int64
# Index(['PRT', 'GBR', 'FRA', 'ESP', 'DEU', 'ITA', 'IRL', 'BEL', 'BRA', 'NLD'], dtype='object')

# %%
# Chart - 9 visualization code
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.pie(top_country,labels=country_name,autopct='%.2f%%')
plt.title('Top 10 country bookings')
plt.subplot(1,2,2)
sns.barplot(x=country_name,y=top_country,palette='pastel',hue=country_name)
plt.title('Top 10 country bookings count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# -  The main aim of using pie chart is to represent the proportions or percentages of different Top 10 countries booking of a whole. It is a circular statistical graphic that is divided into slices to illustrate numerical proportions.so will get an idea which country's booking percentage.
# -  and after i made a Bar plot in which i represented the top 10 countries booking count in which we can see which country has how many bookings in our hotels .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this pie chart and bar plot, I gleaned various insights.
#
# Firstly, I created a pie chart to represent the proportion of booking counts for the top 10 countries. This analysis revealed the percentage of bookings from each country and identified the country with the highest percentage.
#
# Secondly, in the bar plot depicting the booking counts of the top 10 countries, the following observations were made:
#
#   - PRT (Portugal): Portugal has the highest number of bookings in our hotels, totaling 27,355.
#   - GBR (United Kingdom): The United Kingdom secures the second-highest number of bookings, with a total of 10,424.
#   - FRA (France), ESP (Spain), DEU (Germany), ITA (Italy), IRL (Ireland), - BEL (Belgium), BRA (Brazil), NLD (Netherlands): These countries each have fewer than 1,000 bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights will significantly help identify which country has the most and least number of bookings in our hotels.
#
# - For countries with the most bookings like Portugal, United Kingdom, and France, we can strategically provide attractive offers and exceptional services. This approach aims to encourage them to make more bookings and foster loyalty.
#
# - For countries with fewer than 1,000 bookings, offering special discounts can be an effective strategy to increase their bookings.
#
# - Now, addressing countries with very low bookings, which were not mentioned in the plot, requires a targeted marketing approach. Utilizing newspaper ads, television commercials, and social media ads can help reach potential customers in those countries.
#
# Implementing these steps will effectively promote our hotels and contribute to an increase in bookings. As the booking count rises, it will have a positive impact on total revenue generation.

# %% [markdown]
# #### Chart - 10
#
# visualisation of Average Daily rates of both types of hotel.

# %%
# Chart - 10 visualization code
city_mean_adr=city_df['adr'].mean()
resort_mean_adr=resort_df['adr'].mean()
hotel_name=df['hotel'].value_counts().index
lst_value=[city_mean_adr,resort_mean_adr]
print(city_mean_adr)
print(resort_mean_adr)
print(hotel_name)
# Out:
# 111.2737297966999
# 99.55200793745523
# Index(['City Hotel', 'Resort Hotel'], dtype='object')

# %%
# now plotting of adr of both types of hotels.
plt.bar(hotel_name,lst_value,color=['lightgreen','lightblue'])
plt.xlabel('Hotel types')
plt.ylabel('mean daily rates')
plt.title('Bar plotting of mean value of different-different hotel types.')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar plot because it provides a clear visual representation for each category and Here for representing the mean value of both type's of hotel(City hotel , Resort hotel). here i shown the mean value of adr (average daily rates) for both types of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this Bar plot i found some insight are following.
# -  The City hotel has bit more adr comparison to resort hotel.
#   -  city hotel mean adr: 111.271
#   -  resort hotel mean adr:99.05

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impacts are following -
#  -  The gained insight from the chart can be valuable for the hotel management to understand their pricing strategies and revenue generation. The City Hotel may have an opportunity to position itself as a more upscale or luxurious option, attracting guests who are willing to pay higher rates for enhanced services and amenities.
#
#  -  Now if we talk about the resort hotel's adr then for the resort hotel we will need to make plans and strategies which will attract customer for booking by decreasing price of rooms or giving some more extra service with same price.

# %% [markdown]
# #### Chart - 11
#
# Visualisation of cancel request for booked rooms in both type of hotels.

# %%
# Chart - 11 visualization code
total_booking=df['hotel'].value_counts()
print(total_booking)
calcel_booking_count=df.groupby('hotel')['is_canceled'].sum()
print(calcel_booking_count)
hotel_name=df['hotel'].value_counts().index
print(hotel_name)
# Out:
# City Hotel      53271
# Resort Hotel    33512
# Name: hotel, dtype: int64
# hotel
# City Hotel      16034
# Resort Hotel     7946
# Name: is_canceled, dtype: int64
# Index(['City Hotel', 'Resort Hotel'], dtype='object')

# %%
# canceled booking percentage by each type of hotels.
cancel_percentage=(calcel_booking_count/total_booking)*100
print(cancel_percentage)
# Out:
# hotel
# City Hotel      30.098928
# Resort Hotel    23.710910
# dtype: float64

# %%
# visualising the canceled rooms by customer in both types of hotels.
plt.bar(hotel_name,calcel_booking_count,color=['skyblue','lightgreen'])
plt.xlabel('Hotel Name')
plt.ylabel('calcel_booking_count')
plt.title('Cancel booking by Each type of hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I Plotted this chart because i want to visualise the canceled booking from the customer side and what are the number of counts in both types of City and Resort hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this Bar-plot i found following insights.
# - In this bar plot there are total 16035 city hotel booking was canceled by the customer side if we talk about the total number of bookings then it was(Total bookings-53274).
# -  And There are total 7974 resort booking was canceled by the customer side and total booking was 33956.
# - Now let's understand the total percent of cancel booking in total booking so i analysed that there are total 30% of booking was canceled in city-hotel where as 23% of booking was canceled in resort-hotel in total booking percent.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive impact:** In the bar plot, we observe that the booking cancellation percentage in city hotels is 30%, and in resort hotels, it is 24%, which is a significant figure.
#
# It is crucial to identify the specific reasons behind these booking cancellations for both types of hotels.
# Once the reasons are identified, we will work on addressing them, understanding why cancellations are occurring, and devising strategies to counteract this trend.
# - Through meticulous planning and strong strategies, we will create a blueprint outlining the problems and their solutions. The next step involves implementing this blueprint to execute the devised solutions.
# Throughout this process, our focus will be on providing better booking plans, offering the most suitable deals, and assuring customers that we are continuously addressing their concerns.
# Now, let's discuss the negative impact:
#
# - If we fail to find a proper solution for booking cancellations, negative consequences will arise.
# This negative impact can significantly affect the revenue of both types of hotels.
# Additionally, it may damage the hotel's popularity and reputation, which is unacceptable from a business perspective.
# It is imperative to address the issues surrounding booking cancellations to avoid these negative impacts and safeguard the hotels' success and reputation.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# filtering data on hotel types.
city_df=df[df['hotel']=='City Hotel'].copy()
resort_df=df[df['hotel']=='Resort Hotel'].copy()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(x='hotel',y='stays_in_weekend_nights',hue='hotel',data=df)
plt.title('boxplot of stays_in_weekend_nights and types of hotel')
plt.subplot(1,2,2)
sns.boxplot(x='hotel',y='stays_in_week_nights',hue='hotel',data=df)
plt.title('boxplot of stsys_in_week_nights and types of hotel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here i picked two many boxplots because i want to visualise the weekdays stays booking and weekend days stays booking. In which i will get to know in which days mostly customer prefere to visits in our city and resort hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# -  The insights from the boxplot can help hotel management and market teams for better understand booking patterns and guest preferences.
# -  Targeted marketing campaigns can be designed to attract guests seeking longer weekend stays in resort hotels, potentially increasing revenue and occupancy during weekends
#
# -  Negative Growth:
# The presence of outliers with exceptionally long stays in both weekend nights and week nights could also indicate potential booking errors or data issues

# %% [markdown]
# #### Chart - 13

# %%
group_data=df.groupby('hotel')['lead_time'].mean()
print(group_data)
print(hotel_name)
# Out:
# hotel
# City Hotel      77.793922
# Resort Hotel    84.195214
# Name: lead_time, dtype: float64
# Index(['City Hotel', 'Resort Hotel'], dtype='object')

# %%
# Chart - 13 visualization code
sns.barplot(x=hotel_name,y=group_data,hue=hotel_name)
plt.xlabel('hotel name')
plt.ylabel('Mean lead time')
plt.title("visualization between average lead time and type's of hotel")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i picked this box plot because i want to visualise the difference average lead_time between both type's of hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this Bar plot i found the average mean lead_time in both type's of hotel but In which the Value are as follows.
# - City Hotel average lead_time=77.79
# - Resort Hotel average lead_time=83.38
# - Here i can see that Resort type of hotel has bit more mean value of lead time which tell that custome do booking very earlier from the check-in date.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# -  In Hotel booking Dataset the lead time column typically refers to the duration between the date of reservation and date of check-in date.
# In simple words it represents the advance notice or planning period that customers have before arriving at the hotel.
# -  Understanding that resort hotels have a slightly higher meann lead time can help hotel management optimize their revenue management strategies. By offering early bird discounts, special promotions, or other incentives for guests who book in advance, city hotels can encourage more early bookings, leading to better revenue planning and occupancy management.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# First i'll fix the chart size.
plt.figure(figsize=(15,10))
# now plotting the chart
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.title('Correlation of numaric columns in the dataset',fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this Correlation heatmap because i want to see and analyze the correlation and relationship between each variable in the Dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Insights-
#   -  There is positive corelation between 'lead_time' and 'is_canceled' column.this indicates that longer lead times might be associated with a higher likehood of cancellation.
#   -  This chart also indicated that the there are high number of stay_week_nights.
#   -  The number of adults are mostly in types of guests.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Here we will select our columns from the dataset that on which many columns i want to analyse the pairplot .
columns=df[['adr','lead_time','stays_in_weekend_nights','stays_in_week_nights','total_of_special_requests','total_guests']]
sns.pairplot(columns)
plt.title('pair-plot of selected columns')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this Pair plot because i want visualisation of multiple columns pair-wise in the dataset.
# -  the pair plot is especially useful when dealing with small number of a relatively numarical variables.
# The pair plot is a powerfull tool for gaining a comprehensive understanding of the numarical value variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights -
# -  In this pair plot i found that the lead time for most of the customers is below 300 and mostly for those who stays_in_week_nights.
# -  adr has in all segments below than 1000
# - total_guests in each group is less than 10

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer here

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
